# %%
def fun():
    print("hello")
    fun()  #recursion --calling 
    
fun()
# Out:
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# ...

# %%
import sys

sys.setrecursionlimit(2000)
print(sys.getrecursionlimit())

i=0

def fun():
    global i
    for i in fun():
        i+=1
    print("hello",i)
    fun()
    
    
fun()
# Out:
# 2000
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-5-2a076ff9b4ea> in <module>
#      14
#      15
# ---> 16 fun()
#
# <ipython-input-5-2a076ff9b4ea> in fun()
#       8 def fun():
#       9     global i
# ---> 10     for i in fun():
#      11         i+=1
#      12     print("hello",i)
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-5-2a076ff9b4ea> in fun()
#       8 def fun():
#       9     global i
# ---> 10     for i in fun():
#      11         i+=1
#      12     print("hello",i)
#
# RecursionError: maximum recursion depth exceeded
